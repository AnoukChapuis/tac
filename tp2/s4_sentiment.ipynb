# %% [markdown]
# # Sentiment analysis avec Textblob-FR

# %% [markdown]
# Documentation: https://textblob.readthedocs.io/en/dev/

# %% [markdown]
# ## Imports

# %%
import sys
from textblob import Blobber
from textblob_fr import PatternTagger, PatternAnalyzer

# %% [markdown]
# ## Fonction

# %%
tb = Blobber(pos_tagger=PatternTagger(), analyzer=PatternAnalyzer())

def get_sentiment(input_text):
    blob = tb(input_text)
    polarity, subjectivity = blob.sentiment
    polarity_perc = f"{100*abs(polarity):.0f}"
    subjectivity_perc = f"{100*subjectivity:.0f}"
    if polarity > 0:
        polarity_str = f"{polarity_perc}% positive"
    elif polarity < 0:
        polarity_str = f"{polarity_perc}% negative"
    else:
        polarity_str = "neutral"
    if subjectivity > 0:
        subjectivity_str = f"{subjectivity}% subjective"
    else:
        subjectivity_str = "perfectly objective"
    print(f"This text is {polarity_str} and {subjectivity_str}.")

# %% [markdown]
# ## Analyser le sentiment d'une phrase (1960.txt)

# %%
get_sentiment("Le meilleur match depuis longtemps semble qu'il faille plutôt attribuer cela à la mobilité des joueurs postés juste derrière les avants de pointe, et qui surent toujours réagir promptement de la façon la plus heureuse.")
# Out:
# This text is 55% positive and 0.5666666666666667% subjective.

# %%
get_sentiment("Nous n’irons pas plus loin dans la rétrospective : nous avons à juger une oeuvre destinée à un large public et cette œuvre, telle qu’elle a été conçue et réalisée, est un chef- d'œuvre, par son interprétation autant que par son inspiration, grâce à un esprit d’équipe qui évoque on ne sait quelle fraternité d’armes.")
# Out:
# This text is 3% negative and 0.1% subjective.

# %%
get_sentiment("L’homme semblait en proie â une vive colère et tenait à la main un revolver qu’il braqua sur sa belle- mère.")
# Out:
# This text is 54% positive and 0.575% subjective.

# %%
get_sentiment("Celle-ci l’avait rejointe à vélo et, armée d’un marteau, frappa sauvagement sa victime à la tête.")
# Out:
# This text is 20% negative and 0.1% subjective.

# %%
get_sentiment("Dans les années 30, paysans et citadins pauvres allèrent au militarisme parce que le régime d’alors n’avait consolidé l’économie nationale qu’aux dépens des villages et des petits ateliers.")
# Out:
# This text is 9% negative and 0.10000000000000002% subjective.

# %%
get_sentiment("Le Japon entend tous les jours les échos de l’explosion chinoise, qui à certains égards ressemble à la sienne.")
# Out:
# This text is 17% positive and 0.08333333333333333% subjective.

# %%
get_sentiment("Enfin, la fibre elle- même, préalablement foulée, malaxée, triturée, procure un textile qui rivalise avec le lin et le coton et qui, quand il s’agit de la variété appelée sisal, est supérieure à toutes autres en ce qui concerne la résistance : ce qui le fait choisir exclusivement pour les courroies de transmission et pour la ficelle utilisée par les batteuses-lieuses dans le monde entier.")
# Out:
# This text is 13% positive and 0.24% subjective.

# %%
get_sentiment("M. Edmond Kroll, mineur de fond aux houillères de Blanzy, qui habite une cité neuve de la banlieue de Montceau-les-Mines, ne parvient pas à comprendre : depuis dix jours que le personnel donnait des soins au bébé comment ne s’est-on pas aperçu qu’il s’agissait d’une fille ?")
# Out:
# This text is 8% positive and 0.2% subjective.

# %%
get_sentiment("Il a été confirme que 7 millions de dollars seront réservés à des projets de reconversion, destinés à créer de nouveaux emplois dans les régions affectées par la crise charbonnière, notamment en Belgique.")
# Out:
# This text is 15% positive and 0.024999999999999994% subjective.

# %%
get_sentiment("La prétendue unité du Congo, c’est l'Administration belge qui la créait et la maintenait en place.")
# Out:
# This text is neutral and perfectly objective.
