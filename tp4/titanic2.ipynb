# %% [markdown]
# ## Application du word embedding

# %% [markdown]
# **Segmentation**

# %%
# Imports
import os
import sys
import nltk
from nltk.tokenize import sent_tokenize

# %%
# Fichiers d'inputs et d'outputs
infile = "../data/all.txt"
outfile = "../data/sents.txt"

# %%
# Segmentation
