# %% [markdown]
# # Scraping: récupération de la page d'accueil du journal Le Soir
#
# Dans ce notebook, nous créons un robot qui va ouvrir la page d'accueil du site du journal [Le Soir](https://www.lesoir.be/) et récupérer le titre de tous les articles du jour et les stocker dans un fichier csv.

# %% [markdown]
# ## Imports

# %%
import os
import re
import time
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ## Récupération de tous les articles de la page d'accueil

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

articles = []

root_url = f"https://www.lesoir.be"
response = requests.get(root_url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')
for link in soup.find_all("a", {"class":"r-article--link"}):
    title = link.text.strip()
    url = root_url + link.get('href')
    articles.append([url, title])

# %%
# Affichage du nombre d'articles récupérés
len(articles)
# Out:
# 82

# %%
# Affichage des 10 premières entrées
articles[:10]
# Out:
# [['https://www.lesoir.be/474338/article/2022-10-31/la-russie-lance-plus-de-50-missiles-de-croisiere-ce-lundi-sur-lukraine',
#   'La Russie lance plus de 50 missiles de croisière ce lundi sur l’Ukraine'],
#  ['https://www.lesoir.be/474343/article/2022-10-31/lula-elu-president-sur-le-fil-prend-les-manettes-dun-bresil-fracture',
#   'Analyse\nLula, élu président sur le fil, prend les manettes d’un Brésil fracturé'],
#  ['https://www.lesoir.be/474336/article/2022-10-31/crise-energetique-en-deux-semaines-le-chomage-temporaire-quadruple',
#   'Crise énergétique: en deux semaines, le chômage temporaire a quadruplé'],
#  ['https://www.lesoir.be/474285/article/2022-10-31/le-grand-test-des-comparateurs-denergie-cest-la-cacophonie-mais-plus-pour',
#   'Le grand test des comparateurs d’énergie: c’est la cacophonie… mais plus pour longtemps'],
#  ['https://www.lesoir.be/474342/article/2022-10-31/le-prix-du-diesel-en-hausse-ce-mardi',
#   'Le prix du diesel en hausse ce mardi'],
#  ['https://www.lesoir.be/474259/article/2022-10-30/325-chauffeurs-de-la-stib-defendent-le-droit-au-retrait-au-tribunal',
#   '325 chauffeurs de la Stib défendent le droit au retrait au tribunal'],
#  ['https://www.lesoir.be/474040/article/2022-10-31/propos-le-podcast-du-soir-du-31-octobre-cirque-du-soleil-grandes-villes',
#   '«À propos», le podcast du Soir du 31 octobre: Cirque du Soleil, grandes villes wallonnes…'],
#  ['https://www.lesoir.be/474331/article/2022-10-31/cheques-repas-vaccination-contrats-fixes-ce-qui-change-ce-1er-novembre-pour-les',
#   'Chèques-repas, vaccination, contrats fixes… ce qui change ce 1er novembre pour les Belges'],
#  ['https://www.lesoir.be/474265/article/2022-10-30/crown-saison-5-la-chronique-depravee-des-windsor',
#   '«The Crown», saison 5, la chronique dépravée des Windsor'],
#  ['https://www.lesoir.be/474239/article/2022-10-30/bousculade-mortelle-seoul-des-manquements-flagrants-les-autorites-sur-la',
#   'Bousculade mortelle à Séoul: des manquements flagrants, les autorités sur la sellette']]

# %% [markdown]
# ## Création d'un dataframe avec les liens et les titres des articles

# %%
df = pd.DataFrame(articles, columns=['link', 'title'])
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 df = pd.DataFrame(articles, columns=['link', 'title'])
#       2 df
#
# NameError: name 'pd' is not defined

# %%
# Sauvegarde du dataframe dans un fichier csv
df.to_csv(f"../data/lesoir_{time.strftime('%Y%m%d')}.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 2
#       1 # Sauvegarde du dataframe dans un fichier csv
# ----> 2 df.to_csv(f"../data/lesoir_{time.strftime('%Y%m%d')}.csv", index=False)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Téléchargement d'un article et affichage du texte

# %%
# Récupération du premier lien du dataframe
article_url = df.iloc[0][0]

# Ouverture de la page
response = requests.get(article_url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

# Parsing du contenu
title = soup.find("h1").get_text(separator=' ')
chapo = soup.find("r-article--chapo").get_text(separator=' ')
content = soup.find("r-article--section").get_text(separator=' ')

print(title)
print("==================================")
print(chapo)
print("==================================")
print(content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 2
#       1 # Récupération du premier lien du dataframe
# ----> 2 article_url = df.iloc[0][0]
#       4 # Ouverture de la page
#       5 response = requests.get(article_url, headers=headers)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Nettoyage du texte à l'aide d'expressions régulières

# %%
# Suppression de tout ce qui se trouve entre parenthèses
clean_content = re.sub("\([^\)]+\)", " ", content)
# Suppression des espaces multiples
clean_content = re.sub("\s+", " ", clean_content)

print(content)
print("==================================")
print(clean_content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [8], line 2
#       1 # Suppression de tout ce qui se trouve entre parenthèses
# ----> 2 clean_content = re.sub("\([^\)]+\)", " ", content)
#       3 # Suppression des espaces multiples
#       4 clean_content = re.sub("\s+", " ", clean_content)
#
# NameError: name 'content' is not defined

# %% [markdown]
# ### Création d'un fichier avec le contenu de l'article

# %%
with open("../data/lesoir_example.txt", "w") as writer:
    writer.write(f"{title}\n\n{chapo}\n\n{clean_content}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 2
#       1 with open("../data/lesoir_example.txt", "w") as writer:
# ----> 2     writer.write(f"{title}\n\n{chapo}\n\n{clean_content}")
#
# NameError: name 'chapo' is not defined

# %% [markdown]
# ## Pour en savoir plus

# %% [markdown]
# - Le web scraping avec Python: https://realpython.com/beautiful-soup-web-scraper-python/
# - Tutoriel sur les expressions régulières: https://www.w3schools.com/python/python_regex.asp
